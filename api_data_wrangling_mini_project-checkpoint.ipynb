# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY = 'PWWkm4fKRTK5VM3sozas'

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/ ).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules
import requests
import json
import statistics
import pandas as pd
from collections import namedtuple

# %% [raw]
# Note: API's can change a bit with each version, for this exercise it is reccomended to use the "V3" quandl api at `https://www.quandl.com/api/v3/`

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned
url = 'https://www.quandl.com/api/v3/datasets/XFRA/AXV_UADJ.json?start_date=2017-01-01&end_date=2017-12-31&api_key=PWWkm4fKRTK5VM3sozas'

r = requests.get(url)

json_data = r.json()

json_list = json_data['dataset']['data']

res=json.loads(r.text)

json_data
# Out:
# {'dataset': {'id': 46157193,
#   'dataset_code': 'AXV_UADJ',
#   'database_code': 'XFRA',
#   'name': 'Axis Capital Holdings Ltd (AXV) Unadjusted Stock Prices',
#   'description': ' <b>Ticker</b>: AXV <br> <br> <b>Exchange</b>: XFRA <br> <br> Columns: <br> <br> Open,High,Low,Close,Volume are unadjusted and shown in EUR currency. <br> <br> Adjustment Factor shows the factor by which prices are adjusted on days which adjustments take place <br> <br> Adjustment Type is a number representing the type of adjustment. Refer to documentation for more information on these codes.',
#   'refreshed_at': '2021-10-05T05:43:34.318Z',
#   'newest_available_date': '2018-11-30',
#   'oldest_available_date': '2007-01-02',
#   'column_names': ['Date',
#    'Open',
#    'High',
#    'Low',
#    'Close',
#    'Volume',
#    'Adjustment Factor',
#    'Adjustment Type'],
#   'frequency': 'daily',
#   'type': 'Time Series',
#   'premium': True,
#   'limit': None,
#   'transform': None,
#   'column_index': None,
#   'start_date': '2017-01-01',
#   'end_date': '2017-12-31',
#   'data': [['2017-12-29', 40.143, 40.143, 40.026, 40.026, 0.0, None, None],
#    ['2017-12-28', 40.038, 40.038, 40.038, 40.038, 0.0, 0.992087, 17.0],
#    ['2017-12-27', 40.266, 41.263, 40.266, 41.263, 0.0, None, None],
#    ['2017-12-26', 40.997, 40.997, 40.997, 40.997, 0.0, None, None],
#    ['2017-12-25', 40.997, 40.997, 40.997, 40.997, 0.0, None, None],
#    ['2017-12-22', 39.932, 40.999, 39.932, 40.997, 0.0, None, None],
#    ['2017-12-21', 39.861, 39.861, 39.861, 39.861, 0.0, None, None],
#    ['2017-12-20', 40.361, 41.465, 40.361, 41.465, 0.0, None, None],
#    ['2017-12-19', 40.582, 41.622, 40.582, 41.582, 0.0, None, None],
#    ['2017-12-18', 40.902, 40.902, 40.902, 40.902, 0.0, None, None],
#    ['2017-12-15', 40.225, 41.288, 40.225, 41.288, 0.0, None, None],
#    ['2017-12-14', 40.204, 40.204, 40.204, 40.204, 0.0, None, None],
#    ['2017-12-13', 41.016, 41.702, 41.016, 41.702, 0.0, None, None],
#    ['2017-12-12', 40.946, 40.946, 40.946, 40.946, 0.0, None, None],
#    ['2017-12-11', 40.638, 40.638, 40.638, 40.638, 0.0, None, None],
#    ['2017-12-08', 40.372, 41.547, 40.372, 41.547, 0.0, None, None],
#    ['2017-12-07', 40.591, 41.52, 40.591, 41.302, 0.0, None, None],
#    ['2017-12-06', 40.656, 40.656, 40.656, 40.656, 0.0, None, None],
#    ['2017-12-05', 41.119, 41.892, 41.119, 41.65, 0.0, None, None],
#    ['2017-12-04', 42.932, 42.932, 42.65, 42.65, 0.0, None, None],
#    ['2017-12-01', 41.98, 41.98, 41.98, 41.98, 0.0, None, None],
#    ['2017-11-30', 43.007, 44.3, 43.007, 44.3, 150.0, None, None],
#    ['2017-11-29', 42.774, 44.158, 42.774, 44.158, 0.0, None, None],
#    ['2017-11-28', 42.178, 43.285, 42.178, 43.171, 0.0, None, None],
#    ['2017-11-27', 41.16, 41.16, 41.16, 41.16, 0.0, None, None],
#    ['2017-11-24', 41.528, 42.373, 41.528, 42.373, 0.0, None, None],
#    ['2017-11-23', 41.544, 41.544, 41.544, 41.544, 0.0, None, None],
#    ['2017-11-22', 41.728, 42.939, 41.728, 42.939, 0.0, None, None],
#    ['2017-11-21', 41.62, 42.863, 41.62, 42.726, 0.0, None, None],
#    ['2017-11-20', 41.876, 41.876, 41.876, 41.876, 0.0, None, None],
#    ['2017-11-17', 41.727, 41.727, 41.727, 41.727, 0.0, None, None],
#    ['2017-11-16', 42.469, 42.469, 42.469, 42.469, 0.0, None, None],
#    ['2017-11-15', 42.322, 42.904, 42.322, 42.904, 0.0, None, None],
#    ['2017-11-14', 43.086, 43.734, 43.086, 43.734, 0.0, None, None],
#    ['2017-11-13', 43.797, 43.797, 43.797, 43.797, 0.0, None, None],
#    ['2017-11-10', 44.18, 44.729, 44.18, 44.729, 0.0, None, None],
#    ['2017-11-09', 43.97, 43.97, 43.97, 43.97, 0.0, None, None],
#    ['2017-11-08', 44.306, 45.275, 44.306, 45.275, 0.0, None, None],
#    ['2017-11-07', 44.785, 44.785, 44.785, 44.785, 0.0, None, None],
#    ['2017-11-06', 44.612, 44.612, 44.612, 44.612, 0.0, None, None],
#    ['2017-11-03', 44.264, 44.264, 44.264, 44.264, 0.0, None, None],
#    ['2017-11-02', 44.488, 44.488, 44.488, 44.488, 0.0, None, None],
#    ['2017-11-01', 44.458, 45.682, 44.458, 45.682, 0.0, None, None],
#    ['2017-10-31', 44.343, 44.343, 44.343, 44.343, 0.0, None, None],
#    ['2017-10-30', 44.343, 44.343, 44.343, 44.343, 0.0, None, None],
#    ['2017-10-27', 44.897, 45.833, 44.897, 45.833, 0.0, None, None],
#    ['2017-10-26', 45.371, 45.426, 45.371, 45.426, 0.0, None, None],
#    ['2017-10-25', 45.75, 46.975, 45.75, 46.975, 0.0, None, None],
#    ['2017-10-24', 46.053, 46.053, 46.053, 46.053, 0.0, None, None],
#    ['2017-10-23', 46.212, 47.155, 46.212, 47.155, 0.0, None, None],
#    ['2017-10-20', 46.553, 46.553, 46.553, 46.553, 0.0, None, None],
#    ['2017-10-19', 46.046, 46.046, 46.046, 46.046, 0.0, None, None],
#    ['2017-10-18', 46.387, 46.387, 46.387, 46.387, 0.0, None, None],
#    ['2017-10-17', 46.345, 47.689, 46.345, 47.689, 0.0, None, None],
#    ['2017-10-16', 46.662, 46.662, 46.662, 46.662, 0.0, None, None],
#    ['2017-10-13', 45.046, 45.046, 45.046, 45.046, 0.0, None, None],
#    ['2017-10-12', 44.553, 44.553, 44.553, 44.553, 0.0, None, None],
#    ['2017-10-11', 45.135, 45.135, 45.135, 45.135, 0.0, None, None],
#    ['2017-10-10', 45.055, 45.055, 45.055, 45.055, 0.0, None, None],
#    ['2017-10-09', 45.536, 45.536, 45.536, 45.536, 30.0, None, None],
#    ['2017-10-06', 45.79, 45.79, 45.79, 45.79, 0.0, None, None],
#    ['2017-10-05', 45.762, 45.762, 45.762, 45.762, 0.0, 0.993019, 17.0],
#    ['2017-10-04', 46.271, 46.271, 46.271, 46.271, 0.0, None, None],
#    ['2017-10-03', 47.3, 47.3, 47.3, 47.3, 0.0, None, None],
#    ['2017-10-02', 47.3, 47.3, 47.3, 47.3, 0.0, None, None],
#    ['2017-09-29', 46.15, 46.15, 46.15, 46.15, 0.0, None, None],
#    ['2017-09-28', 46.244, 46.244, 46.244, 46.244, 0.0, None, None],
#    ['2017-09-27', 45.716, 47.503, 45.716, 47.503, 0.0, None, None],
#    ['2017-09-26', 45.721, 46.663, 45.721, 46.57, 0.0, None, None],
#    ['2017-09-25', 45.526, 46.713, 45.526, 46.713, 0.0, None, None],
#    ['2017-09-22', 45.688, 45.688, 45.688, 45.688, 0.0, None, None],
#    ['2017-09-21', 45.945, 45.945, 45.945, 45.945, 0.0, None, None],
#    ['2017-09-20', 45.026, 45.026, 45.026, 45.026, 0.0, None, None],
#    ['2017-09-19', 45.739, 45.739, 45.739, 45.739, 0.0, None, None],
#    ['2017-09-18', 46.352, 47.562, 46.352, 47.433, 0.0, None, None],
#    ['2017-09-15', 46.151, 46.151, 46.151, 46.151, 0.0, None, None],
#    ['2017-09-14', 47.565, 47.565, 47.565, 47.565, 0.0, None, None],
#    ['2017-09-13', 47.109, 48.157, 47.109, 48.157, 0.0, None, None],
#    ['2017-09-12', 46.53, 46.53, 46.53, 46.53, 0.0, None, None],
#    ['2017-09-11', 47.69, 48.04, 47.69, 48.04, 0.0, None, None],
#    ['2017-09-08', 41.558, 41.558, 41.558, 41.558, 0.0, None, None],
#    ['2017-09-07', 44.341, 44.341, 44.341, 44.341, 0.0, None, None],
#    ['2017-09-06', 44.635, 44.635, 44.635, 44.635, 0.0, None, None],
#    ['2017-09-05', 48.364, 48.364, 48.364, 48.364, 0.0, None, None],
#    ['2017-09-04', 48.364, 48.364, 48.364, 48.364, 0.0, None, None],
#    ['2017-09-01', 48.285, 48.285, 48.285, 48.285, 0.0, None, None],
#    ['2017-08-31', 48.486, 48.486, 48.486, 48.486, 0.0, None, None],
#    ['2017-08-30', 48.39, 49.65, 48.39, 49.65, 0.0, None, None],
#    ['2017-08-29', 48.101, 48.101, 48.101, 48.101, 0.0, None, None],
#    ['2017-08-28', 50.059, 50.788, 49.857, 49.857, 0.0, None, None],
#    ['2017-08-25', 50.296, 51.601, 50.296, 51.279, 0.0, None, None],
#    ['2017-08-24', 51.107, 51.107, 51.107, 51.107, 0.0, None, None],
#    ['2017-08-23', 51.085, 51.085, 51.085, 51.085, 0.0, None, None],
#    ['2017-08-22', 50.935, 51.085, 50.935, 51.085, 0.0, None, None],
#    ['2017-08-21', 51.51, 52.405, 51.51, 52.405, 0.0, None, None],
#    ['2017-08-18', 51.2, 52.617, 51.2, 52.617, 0.0, None, None],
#    ['2017-08-17', 51.767, 51.767, 51.767, 51.767, 0.0, None, None],
#    ['2017-08-16', 52.057, 53.593, 52.057, 53.593, 0.0, None, None],
#    ['2017-08-15', 52.146, 52.146, 52.146, 52.146, 0.0, None, None],
#    ['2017-08-14', 51.431, 53.25, 51.431, 53.25, 0.0, None, None],
#    ['2017-08-11', 51.839, 51.839, 51.839, 51.839, 0.0, None, None],
#    ['2017-08-10', 52.346, 52.346, 52.346, 52.346, 0.0, None, None],
#    ['2017-08-09', 52.303, 52.303, 52.303, 52.303, 0.0, None, None],
#    ['2017-08-08', 51.97, 53.144, 51.97, 53.144, 0.0, None, None],
#    ['2017-08-07', 52.355, 52.355, 52.355, 52.355, 0.0, None, None],
#    ['2017-08-04', 52.016, 53.431, 52.016, 53.431, 0.0, None, None],
#    ['2017-08-03', 52.29, 53.503, 52.29, 53.503, 0.0, None, None],
#    ['2017-08-02', 52.308, 53.658, 52.308, 53.658, 0.0, None, None],
#    ['2017-08-01', 52.046, 52.046, 52.046, 52.046, 0.0, None, None],
#    ['2017-07-31', 51.853, 51.853, 51.853, 51.853, 0.0, None, None],
#    ['2017-07-28', 51.58, 51.58, 51.58, 51.58, 0.0, None, None],
#    ['2017-07-27', 52.694, 52.694, 52.694, 52.694, 0.0, None, None],
#    ['2017-07-26', 53.574, 53.574, 53.574, 53.574, 0.0, None, None],
#    ['2017-07-25', 53.282, 53.282, 53.282, 53.282, 0.0, None, None],
#    ['2017-07-24', 53.163, 54.45, 53.163, 54.45, 0.0, None, None],
#    ['2017-07-21', 52.934, 52.934, 52.934, 52.934, 0.0, None, None],
#    ['2017-07-20', 53.309, 53.309, 53.309, 53.309, 0.0, None, None],
#    ['2017-07-19', 52.638, 52.638, 52.638, 52.638, 0.0, None, None],
#    ['2017-07-18', 52.541, 52.541, 52.541, 52.541, 0.0, None, None],
#    ['2017-07-17', 53.081, 54.163, 53.081, 54.163, 0.0, None, None],
#    ['2017-07-14', 53.37, 54.175, 53.37, 54.175, 0.0, None, None],
#    ['2017-07-13', 53.137, 54.371, 53.137, 54.371, 0.0, None, None],
#    ['2017-07-12', 52.911, 52.911, 52.911, 52.911, 0.0, None, None],
#    ['2017-07-11', 53.608, 53.608, 53.608, 53.608, 0.0, None, None],
#    ['2017-07-10', 53.539, 53.539, 53.539, 53.539, 0.0, None, None],
#    ['2017-07-07', 52.994, 52.994, 52.994, 52.994, 0.0, None, None],
#    ['2017-07-06', 55.196, 55.196, 54.998, 54.998, 0.0, None, None],
#    ['2017-07-05', 55.132, 56.423, 55.132, 56.423, 0.0, None, None],
#    ['2017-07-04', 55.12, 55.12, 55.12, 55.12, 0.0, None, None],
#    ['2017-07-03', 54.007, 56.155, 54.007, 56.155, 0.0, None, None],
#    ['2017-06-30', 53.968, 53.968, 53.968, 53.968, 0.0, None, None],
#    ['2017-06-29', 53.728, 55.175, 53.728, 55.175, 0.0, None, None],
#    ['2017-06-28', 55.75, 55.75, 55.75, 55.75, 0.0, 0.994009, 17.0],
#    ['2017-06-27', 54.616, 55.75, 54.616, 55.75, 0.0, None, None],
#    ['2017-06-26', 54.086, 54.086, 54.086, 54.086, 0.0, None, None],
#    ['2017-06-23', 54.782, 54.782, 54.782, 54.782, 0.0, None, None],
#    ['2017-06-22', 55.288, 55.288, 55.288, 55.288, 0.0, None, None],
#    ['2017-06-21', 55.857, 55.857, 55.857, 55.857, 0.0, None, None],
#    ['2017-06-20', 56.049, 56.049, 56.049, 56.049, 0.0, None, None],
#    ['2017-06-19', 55.499, 55.499, 55.499, 55.499, 0.0, None, None],
#    ['2017-06-16', 55.335, 55.335, 55.335, 55.335, 0.0, None, None],
#    ['2017-06-15', 55.554, 56.848, 55.554, 56.848, 0.0, None, None],
#    ['2017-06-14', 55.378, 55.378, 55.378, 55.378, 0.0, None, None],
#    ['2017-06-13', 55.499, 56.866, 55.499, 56.866, 0.0, None, None],
#    ['2017-06-12', 55.198, 55.198, 55.198, 55.198, 0.0, None, None],
#    ['2017-06-09', 55.077, 55.077, 55.077, 55.077, 0.0, None, None],
#    ['2017-06-08', 54.547, 55.81, 54.547, 55.81, 0.0, None, None],
#    ['2017-06-07', 54.798, 56.2, 54.798, 56.2, 0.0, None, None],
#   'order': None,
#   'database_id': 15302}}

# %%
open_list = []

for list in json_list:
    open_list.append(list[1])

max(open_list)
# Out:
# 68.5

# %%
min(open_list)
# Out:
# 39.861

# %%
diff_list = []

for list in json_list:
    diff_list.append(list[2]-list[3])
    
max(diff_list)
# Out:
# 2.5

# %%
#dd = {}

# %%
#for list in json_list:
    dd[list[0]]  = list[4]
    
#dd
# Out:
# {'2017-12-29': 40.026,
#  '2017-12-28': 40.038,
#  '2017-12-27': 41.263,
#  '2017-12-26': 40.997,
#  '2017-12-25': 40.997,
#  '2017-12-22': 40.997,
#  '2017-12-21': 39.861,
#  '2017-12-20': 41.465,
#  '2017-12-19': 41.582,
#  '2017-12-18': 40.902,
#  '2017-12-15': 41.288,
#  '2017-12-14': 40.204,
#  '2017-12-13': 41.702,
#  '2017-12-12': 40.946,
#  '2017-12-11': 40.638,
#  '2017-12-08': 41.547,
#  '2017-12-07': 41.302,
#  '2017-12-06': 40.656,
#  '2017-12-05': 41.65,
#  '2017-12-04': 42.65,
#  '2017-12-01': 41.98,
#  '2017-11-30': 44.3,
#  '2017-11-29': 44.158,
#  '2017-11-28': 43.171,
#  '2017-11-27': 41.16,
#  '2017-11-24': 42.373,
#  '2017-11-23': 41.544,
#  '2017-11-22': 42.939,
#  '2017-11-21': 42.726,
#  '2017-11-20': 41.876,
#  '2017-11-17': 41.727,
#  '2017-11-16': 42.469,
#  '2017-11-15': 42.904,
#  '2017-11-14': 43.734,
#  '2017-11-13': 43.797,
#  '2017-11-10': 44.729,
#  '2017-11-09': 43.97,
#  '2017-11-08': 45.275,
#  '2017-11-07': 44.785,
#  '2017-11-06': 44.612,
#  '2017-11-03': 44.264,
#  '2017-11-02': 44.488,
#  '2017-11-01': 45.682,
#  '2017-10-31': 44.343,
#  '2017-10-30': 44.343,
#  '2017-10-27': 45.833,
#  '2017-10-26': 45.426,
#  '2017-10-25': 46.975,
#  '2017-10-24': 46.053,
#  '2017-10-23': 47.155,
#  '2017-10-20': 46.553,
#  '2017-10-19': 46.046,
#  '2017-10-18': 46.387,
#  '2017-10-17': 47.689,
#  '2017-10-16': 46.662,
#  '2017-10-13': 45.046,
#  '2017-10-12': 44.553,
#  '2017-10-11': 45.135,
#  '2017-10-10': 45.055,
#  '2017-10-09': 45.536,
#  '2017-10-06': 45.79,
#  '2017-10-05': 45.762,
#  '2017-10-04': 46.271,
#  '2017-10-03': 47.3,
#  '2017-10-02': 47.3,
#  '2017-09-29': 46.15,
#  '2017-09-28': 46.244,
#  '2017-09-27': 47.503,
#  '2017-09-26': 46.57,
#  '2017-09-25': 46.713,
#  '2017-09-22': 45.688,
#  '2017-09-21': 45.945,
#  '2017-09-20': 45.026,
#  '2017-09-19': 45.739,
#  '2017-09-18': 47.433,
#  '2017-09-15': 46.151,
#  '2017-09-14': 47.565,
#  '2017-09-13': 48.157,
#  '2017-09-12': 46.53,
#  '2017-09-11': 48.04,
#  '2017-09-08': 41.558,
#  '2017-09-07': 44.341,
#  '2017-09-06': 44.635,
#  '2017-04-21': 60.494,
#  '2017-04-20': 59.976,
#  '2017-04-19': 59.184,
#  '2017-04-18': 59.184,
#  '2017-04-17': 59.107,
#  '2017-04-14': 59.107,
#  '2017-04-13': 59.107,
#  '2017-04-12': 59.659,
#  '2017-04-11': 59.679,
#  '2017-04-10': 61.092,
#  '2017-04-07': 61.227,
#  '2017-04-06': 60.952,
#  '2017-04-05': 60.057,
#  '2017-04-04': 59.706,
#  '2017-04-03': 61.347,
#  '2017-03-31': 61.369,
#  '2017-03-30': 60.636,
#  '2017-03-29': 59.216,
#  '2017-03-28': 58.336,
#  '2017-03-27': 59.346,
#  '2017-03-24': 60.535,
#  '2017-03-23': 60.547,
#  '2017-03-22': 60.225,
#  '2017-03-21': 59.545,
#  '2017-03-20': 61.78,
#  '2017-03-17': 61.796,
#  '2017-03-16': 62.515,
#  '2017-03-15': 63.177,
#  '2017-03-14': 63.085,
#  '2017-03-13': 61.192,
#  '2017-03-10': 63.261,
#  '2017-03-09': 63.501,
#  '2017-03-08': 63.637,
#  '2017-03-07': 63.273,
#  '2017-03-06': 66.0,
#  '2017-03-03': 64.867,
#  '2017-03-02': 64.104,
#  '2017-03-01': 62.592,
#  '2017-02-28': 61.683,
#  '2017-02-27': 62.132,
#  '2017-02-24': 61.91,
#  '2017-02-23': 61.97,
#  '2017-02-22': 62.232,
#  '2017-02-21': 61.995,
#  '2017-02-20': 61.51,
#  '2017-02-17': 61.352,
#  '2017-02-16': 62.436,
#  '2017-02-15': 62.569,
#  '2017-02-14': 60.792,
#  '2017-02-13': 60.429,
#  '2017-02-10': 60.445,
#  '2017-02-09': 64.0,
#  '2017-02-08': 60.296,
#  '2017-02-07': 59.84,
#  '2017-02-06': 59.002,
#  '2017-02-03': 59.063,
#  '2017-02-02': 57.017,
#  '2017-02-01': 56.541,
#  '2017-01-31': 57.212,
#  '2017-01-30': 57.352,
#  '2017-01-27': 58.121,
#  '2017-01-26': 57.67,
#  '2017-01-25': 57.468,
#  '2017-01-24': 57.19,
#  '2017-01-23': 58.597,
#  '2017-01-20': 57.757,
#  '2017-01-19': 58.503,
#  '2017-01-18': 57.606,
#  '2017-01-17': 58.373,
#  '2017-01-16': 58.604,
#  '2017-01-13': 58.134,
#  '2017-01-12': 58.189,
#  '2017-01-11': 58.526,
#  '2017-01-10': 58.441,
#  '2017-01-09': 59.629,
#  '2017-01-06': 59.052,
#  '2017-01-05': 59.456,
#  '2017-01-04': 59.685,
#  '2017-01-03': 59.568,
#  '2017-01-02': 59.375}

# %%
def create_daily_dict(data):
    """
    Takes a dictionary from a JSON payload in a set format as returned by
    Quandl (now NASDAQ Data) and turns it into a dictionary with dates as
    the key and the daily metrics as a named tuple.
    
    Parameters
    ----------
    data: dict
        Properly formatted dictionary matching the Quandl JSON payload.
        The function assumes that this dict is formatted as expected,
        the function will throw an error if not.
    
    Returns
    -------
    dict
        Dictionary with each date as the key (YYYY-MM-DD) and a
        named tuple as the value using the column_names returned
        in the JSON payload.
    """
    cols = [x.replace(' ', '_').lower() for x in data['dataset']['column_names'][1:]]
    FSE_Date = namedtuple('FSE_Date', cols)
    daily_dict = {x[0]: FSE_Date(*x[1:]) for x in data['dataset']['data']}
    return {k: daily_dict[k] for k in sorted(daily_dict)}

# %%
dd = create_daily_dict(res)

# %%
dd
# Out:
# {'2017-01-02': FSE_Date(open=59.375, high=59.375, low=59.375, close=59.375, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-03': FSE_Date(open=59.568, high=59.568, low=59.568, close=59.568, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-04': FSE_Date(open=59.685, high=59.685, low=59.685, close=59.685, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-05': FSE_Date(open=59.456, high=59.456, low=59.456, close=59.456, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-06': FSE_Date(open=59.052, high=59.052, low=59.052, close=59.052, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-09': FSE_Date(open=59.629, high=59.629, low=59.629, close=59.629, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-10': FSE_Date(open=58.441, high=58.441, low=58.441, close=58.441, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-11': FSE_Date(open=58.526, high=58.526, low=58.526, close=58.526, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-12': FSE_Date(open=58.189, high=58.189, low=58.189, close=58.189, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-13': FSE_Date(open=58.134, high=58.134, low=58.134, close=58.134, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-16': FSE_Date(open=58.604, high=58.604, low=58.604, close=58.604, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-17': FSE_Date(open=58.373, high=58.373, low=58.373, close=58.373, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-18': FSE_Date(open=57.606, high=57.606, low=57.606, close=57.606, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-19': FSE_Date(open=58.503, high=58.503, low=58.503, close=58.503, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-20': FSE_Date(open=57.757, high=57.757, low=57.757, close=57.757, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-23': FSE_Date(open=57.186, high=58.597, low=57.186, close=58.597, volume=73.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-24': FSE_Date(open=57.19, high=57.19, low=57.19, close=57.19, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-25': FSE_Date(open=57.468, high=57.468, low=57.468, close=57.468, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-26': FSE_Date(open=57.67, high=57.67, low=57.67, close=57.67, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-27': FSE_Date(open=58.121, high=58.121, low=58.121, close=58.121, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-30': FSE_Date(open=57.352, high=57.352, low=57.352, close=57.352, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-01-31': FSE_Date(open=57.212, high=57.212, low=57.212, close=57.212, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-02-01': FSE_Date(open=56.541, high=56.541, low=56.541, close=56.541, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-02-02': FSE_Date(open=57.017, high=57.017, low=57.017, close=57.017, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-02-03': FSE_Date(open=59.063, high=59.063, low=59.063, close=59.063, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-02-06': FSE_Date(open=59.002, high=59.002, low=59.002, close=59.002, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-02-07': FSE_Date(open=59.84, high=59.84, low=59.84, close=59.84, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-02-08': FSE_Date(open=60.296, high=60.296, low=60.296, close=60.296, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-02-09': FSE_Date(open=64.0, high=64.0, low=64.0, close=64.0, volume=10.0, adjustment_factor=None, adjustment_type=None),
#  '2017-02-10': FSE_Date(open=60.445, high=60.445, low=60.445, close=60.445, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-02-13': FSE_Date(open=60.429, high=60.429, low=60.429, close=60.429, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-02-14': FSE_Date(open=60.792, high=60.792, low=60.792, close=60.792, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-02-15': FSE_Date(open=62.569, high=62.569, low=62.569, close=62.569, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-02-16': FSE_Date(open=62.436, high=62.436, low=62.436, close=62.436, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-02-17': FSE_Date(open=61.352, high=61.352, low=61.352, close=61.352, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-02-20': FSE_Date(open=61.51, high=61.51, low=61.51, close=61.51, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-02-21': FSE_Date(open=61.995, high=61.995, low=61.995, close=61.995, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-02-22': FSE_Date(open=62.232, high=62.232, low=62.232, close=62.232, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-02-23': FSE_Date(open=61.97, high=61.97, low=61.97, close=61.97, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-02-24': FSE_Date(open=61.91, high=61.91, low=61.91, close=61.91, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-02-27': FSE_Date(open=62.132, high=62.132, low=62.132, close=62.132, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-02-28': FSE_Date(open=61.683, high=61.683, low=61.683, close=61.683, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-01': FSE_Date(open=62.592, high=62.592, low=62.592, close=62.592, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-02': FSE_Date(open=64.104, high=64.104, low=64.104, close=64.104, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-03': FSE_Date(open=63.541, high=64.867, low=63.541, close=64.867, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-06': FSE_Date(open=68.5, high=68.5, low=66.0, close=66.0, volume=98.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-07': FSE_Date(open=61.759, high=63.273, low=61.759, close=63.273, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-08': FSE_Date(open=61.904, high=63.637, low=61.904, close=63.637, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-09': FSE_Date(open=62.209, high=63.501, low=62.209, close=63.501, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-10': FSE_Date(open=61.862, high=63.261, low=61.862, close=63.261, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-13': FSE_Date(open=61.192, high=61.192, low=61.192, close=61.192, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-14': FSE_Date(open=61.648, high=63.085, low=61.648, close=63.085, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-15': FSE_Date(open=61.656, high=63.177, low=61.656, close=63.177, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-16': FSE_Date(open=60.869, high=62.515, low=60.869, close=62.515, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-17': FSE_Date(open=60.46, high=61.796, low=60.46, close=61.796, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-20': FSE_Date(open=60.379, high=61.78, low=60.379, close=61.78, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-21': FSE_Date(open=59.545, high=59.545, low=59.545, close=59.545, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-22': FSE_Date(open=59.014, high=60.225, low=59.014, close=60.225, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-23': FSE_Date(open=59.137, high=60.547, low=59.137, close=60.547, volume=10.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-24': FSE_Date(open=58.971, high=60.535, low=58.971, close=60.535, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-27': FSE_Date(open=58.582, high=59.346, low=58.582, close=59.346, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-28': FSE_Date(open=58.336, high=58.336, low=58.336, close=58.336, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-29': FSE_Date(open=59.216, high=59.216, low=59.216, close=59.216, volume=0.0, adjustment_factor=0.99395, adjustment_type=17.0),
#  '2017-03-30': FSE_Date(open=59.097, high=60.636, low=59.097, close=60.636, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-03-31': FSE_Date(open=60.096, high=61.369, low=60.096, close=61.369, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-04-03': FSE_Date(open=59.819, high=61.347, low=59.819, close=61.347, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-04-04': FSE_Date(open=59.706, high=59.706, low=59.706, close=59.706, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-04-05': FSE_Date(open=60.057, high=60.057, low=60.057, close=60.057, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-04-06': FSE_Date(open=59.562, high=60.952, low=59.562, close=60.952, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-04-07': FSE_Date(open=59.661, high=61.227, low=59.661, close=61.227, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-04-10': FSE_Date(open=59.507, high=61.092, low=59.507, close=61.092, volume=2.0, adjustment_factor=None, adjustment_type=None),
#  '2017-04-11': FSE_Date(open=59.679, high=59.679, low=59.679, close=59.679, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-04-12': FSE_Date(open=59.659, high=59.659, low=59.659, close=59.659, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-04-13': FSE_Date(open=59.107, high=59.107, low=59.107, close=59.107, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-04-14': FSE_Date(open=59.107, high=59.107, low=59.107, close=59.107, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-04-17': FSE_Date(open=59.107, high=59.107, low=59.107, close=59.107, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-04-18': FSE_Date(open=59.184, high=59.184, low=59.184, close=59.184, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-04-19': FSE_Date(open=59.184, high=59.184, low=59.184, close=59.184, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-04-20': FSE_Date(open=58.71, high=59.976, low=58.71, close=59.976, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-04-21': FSE_Date(open=59.029, high=60.494, low=59.029, close=60.494, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-04-24': FSE_Date(open=58.176, high=60.167, low=58.176, close=60.167, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-04-25': FSE_Date(open=58.393, high=60.242, low=58.393, close=60.242, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-04-26': FSE_Date(open=58.984, high=60.869, low=58.984, close=60.869, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-04-27': FSE_Date(open=59.428, high=60.341, low=59.428, close=60.341, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-04-28': FSE_Date(open=59.098, high=60.157, low=59.098, close=60.157, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-01': FSE_Date(open=60.157, high=60.157, low=60.157, close=60.157, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-02': FSE_Date(open=57.462, high=58.889, low=57.462, close=58.889, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-03': FSE_Date(open=57.512, high=58.852, low=57.512, close=58.852, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-04': FSE_Date(open=57.733, high=57.733, low=57.733, close=57.733, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-05': FSE_Date(open=56.949, high=58.333, low=56.949, close=58.333, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-08': FSE_Date(open=56.919, high=58.624, low=56.919, close=58.624, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-09': FSE_Date(open=56.666, high=58.173, low=56.666, close=58.173, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-10': FSE_Date(open=56.083, high=57.53, low=56.083, close=57.53, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-11': FSE_Date(open=56.419, high=57.64, low=56.419, close=57.64, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-12': FSE_Date(open=55.882, high=56.906, low=55.882, close=56.906, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-15': FSE_Date(open=54.798, high=55.877, low=54.798, close=55.877, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-16': FSE_Date(open=54.632, high=55.664, low=54.632, close=55.664, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-17': FSE_Date(open=54.151, high=55.336, low=54.151, close=55.336, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-18': FSE_Date(open=53.376, high=54.875, low=53.376, close=54.875, volume=40.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-19': FSE_Date(open=53.838, high=53.838, low=53.838, close=53.838, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-22': FSE_Date(open=53.945, high=55.168, low=53.945, close=55.168, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-23': FSE_Date(open=53.497, high=54.811, low=53.497, close=54.811, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-24': FSE_Date(open=54.258, high=55.686, low=54.258, close=55.686, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-25': FSE_Date(open=54.621, high=54.621, low=54.621, close=54.621, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-26': FSE_Date(open=55.332, high=56.888, low=55.332, close=56.888, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-29': FSE_Date(open=55.42, high=55.42, low=55.42, close=55.42, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-30': FSE_Date(open=55.554, high=56.529, low=55.554, close=56.529, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-05-31': FSE_Date(open=55.057, high=56.413, low=55.057, close=56.413, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-06-01': FSE_Date(open=55.585, high=57.236, low=55.585, close=57.236, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-06-02': FSE_Date(open=56.264, high=56.264, low=56.264, close=56.264, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-06-05': FSE_Date(open=56.264, high=56.264, low=56.264, close=56.264, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-06-06': FSE_Date(open=55.482, high=56.372, low=55.482, close=56.372, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-06-07': FSE_Date(open=54.798, high=56.2, low=54.798, close=56.2, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-06-08': FSE_Date(open=54.547, high=55.81, low=54.547, close=55.81, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-06-09': FSE_Date(open=55.077, high=55.077, low=55.077, close=55.077, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017
volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-08-07': FSE_Date(open=52.355, high=52.355, low=52.355, close=52.355, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-08-08': FSE_Date(open=51.97, high=53.144, low=51.97, close=53.144, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-08-09': FSE_Date(open=52.303, high=52.303, low=52.303, close=52.303, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-08-10': FSE_Date(open=52.346, high=52.346, low=52.346, close=52.346, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-08-11': FSE_Date(open=51.839, high=51.839, low=51.839, close=51.839, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-08-14': FSE_Date(open=51.431, high=53.25, low=51.431, close=53.25, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-08-15': FSE_Date(open=52.146, high=52.146, low=52.146, close=52.146, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-08-16': FSE_Date(open=52.057, high=53.593, low=52.057, close=53.593, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-08-17': FSE_Date(open=51.767, high=51.767, low=51.767, close=51.767, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-08-18': FSE_Date(open=51.2, high=52.617, low=51.2, close=52.617, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-08-21': FSE_Date(open=51.51, high=52.405, low=51.51, close=52.405, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-08-22': FSE_Date(open=50.935, high=51.085, low=50.935, close=51.085, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-08-23': FSE_Date(open=51.085, high=51.085, low=51.085, close=51.085, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-08-24': FSE_Date(open=51.107, high=51.107, low=51.107, close=51.107, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-08-25': FSE_Date(open=50.296, high=51.601, low=50.296, close=51.279, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-08-28': FSE_Date(open=50.059, high=50.788, low=49.857, close=49.857, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-08-29': FSE_Date(open=48.101, high=48.101, low=48.101, close=48.101, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-08-30': FSE_Date(open=48.39, high=49.65, low=48.39, close=49.65, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-08-31': FSE_Date(open=48.486, high=48.486, low=48.486, close=48.486, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-01': FSE_Date(open=48.285, high=48.285, low=48.285, close=48.285, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-04': FSE_Date(open=48.364, high=48.364, low=48.364, close=48.364, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-05': FSE_Date(open=48.364, high=48.364, low=48.364, close=48.364, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-06': FSE_Date(open=44.635, high=44.635, low=44.635, close=44.635, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-07': FSE_Date(open=44.341, high=44.341, low=44.341, close=44.341, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-08': FSE_Date(open=41.558, high=41.558, low=41.558, close=41.558, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-11': FSE_Date(open=47.69, high=48.04, low=47.69, close=48.04, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-12': FSE_Date(open=46.53, high=46.53, low=46.53, close=46.53, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-13': FSE_Date(open=47.109, high=48.157, low=47.109, close=48.157, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-14': FSE_Date(open=47.565, high=47.565, low=47.565, close=47.565, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-15': FSE_Date(open=46.151, high=46.151, low=46.151, close=46.151, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-18': FSE_Date(open=46.352, high=47.562, low=46.352, close=47.433, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-19': FSE_Date(open=45.739, high=45.739, low=45.739, close=45.739, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-20': FSE_Date(open=45.026, high=45.026, low=45.026, close=45.026, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-21': FSE_Date(open=45.945, high=45.945, low=45.945, close=45.945, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-22': FSE_Date(open=45.688, high=45.688, low=45.688, close=45.688, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-25': FSE_Date(open=45.526, high=46.713, low=45.526, close=46.713, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-26': FSE_Date(open=45.721, high=46.663, low=45.721, close=46.57, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-27': FSE_Date(open=45.716, high=47.503, low=45.716, close=47.503, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-28': FSE_Date(open=46.244, high=46.244, low=46.244, close=46.244, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-09-29': FSE_Date(open=46.15, high=46.15, low=46.15, close=46.15, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-02': FSE_Date(open=47.3, high=47.3, low=47.3, close=47.3, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-03': FSE_Date(open=47.3, high=47.3, low=47.3, close=47.3, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-04': FSE_Date(open=46.271, high=46.271, low=46.271, close=46.271, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-05': FSE_Date(open=45.762, high=45.762, low=45.762, close=45.762, volume=0.0, adjustment_factor=0.993019, adjustment_type=17.0),
#  '2017-10-06': FSE_Date(open=45.79, high=45.79, low=45.79, close=45.79, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-09': FSE_Date(open=45.536, high=45.536, low=45.536, close=45.536, volume=30.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-10': FSE_Date(open=45.055, high=45.055, low=45.055, close=45.055, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-11': FSE_Date(open=45.135, high=45.135, low=45.135, close=45.135, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-12': FSE_Date(open=44.553, high=44.553, low=44.553, close=44.553, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-13': FSE_Date(open=45.046, high=45.046, low=45.046, close=45.046, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-16': FSE_Date(open=46.662, high=46.662, low=46.662, close=46.662, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-17': FSE_Date(open=46.345, high=47.689, low=46.345, close=47.689, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-18': FSE_Date(open=46.387, high=46.387, low=46.387, close=46.387, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-19': FSE_Date(open=46.046, high=46.046, low=46.046, close=46.046, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-20': FSE_Date(open=46.553, high=46.553, low=46.553, close=46.553, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-23': FSE_Date(open=46.212, high=47.155, low=46.212, close=47.155, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-24': FSE_Date(open=46.053, high=46.053, low=46.053, close=46.053, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-25': FSE_Date(open=45.75, high=46.975, low=45.75, close=46.975, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-26': FSE_Date(open=45.371, high=45.426, low=45.371, close=45.426, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-27': FSE_Date(open=44.897, high=45.833, low=44.897, close=45.833, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-30': FSE_Date(open=44.343, high=44.343, low=44.343, close=44.343, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-10-31': FSE_Date(open=44.343, high=44.343, low=44.343, close=44.343, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-01': FSE_Date(open=44.458, high=45.682, low=44.458, close=45.682, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-02': FSE_Date(open=44.488, high=44.488, low=44.488, close=44.488, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-03': FSE_Date(open=44.264, high=44.264, low=44.264, close=44.264, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-06': FSE_Date(open=44.612, high=44.612, low=44.612, close=44.612, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-07': FSE_Date(open=44.785, high=44.785, low=44.785, close=44.785, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-08': FSE_Date(open=44.306, high=45.275, low=44.306, close=45.275, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-09': FSE_Date(open=43.97, high=43.97, low=43.97, close=43.97, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-10': FSE_Date(open=44.18, high=44.729, low=44.18, close=44.729, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-13': FSE_Date(open=43.797, high=43.797, low=43.797, close=43.797, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-14': FSE_Date(open=43.086, high=43.734, low=43.086, close=43.734, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-15': FSE_Date(open=42.322, high=42.904, low=42.322, close=42.904, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-16': FSE_Date(open=42.469, high=42.469, low=42.469, close=42.469, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-17': FSE_Date(open=41.727, high=41.727, low=41.727, close=41.727, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-20': FSE_Date(open=41.876, high=41.876, low=41.876, close=41.876, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-21': FSE_Date(open=41.62, high=42.863, low=41.62, close=42.726, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-22': FSE_Date(open=41.728, high=42.939, low=41.728, close=42.939, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-23': FSE_Date(open=41.544, high=41.544, low=41.544, close=41.544, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-24': FSE_Date(open=41.528, high=42.373, low=41.528, close=42.373, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-27': FSE_Date(open=41.16, high=41.16, low=41.16, close=41.16, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-28': FSE_Date(open=42.178, high=43.285, low=42.178, close=43.171, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-29': FSE_Date(open=42.774, high=44.158, low=42.774, close=44.158, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-11-30': FSE_Date(open=43.007, high=44.3, low=43.007, close=44.3, volume=150.0, adjustment_factor=None, adjustment_type=None),
#  '2017-12-01': FSE_Date(open=41.98, high=41.98, low=41.98, close=41.98, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-12-04': FSE_Date(open=42.932, high=42.932, low=42.65, close=42.65, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-12-05': FSE_Date(open=41.119, high=41.892, low=41.119, close=41.65, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-12-06': FSE_Date(open=40.656, high=40.656, low=40.656, close=40.656, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-12-07': FSE_Date(open=40.591, high=41.52, low=40.591, close=41.302, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-12-08': FSE_Date(open=40.372, high=41.547, low=40.372, close=41.547, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-12-11': FSE_Date(open=40.638, high=40.638, low=40.638, close=40.638, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-12-12': FSE_Date(open=40.946, high=40.946, low=40.946, close=40.946, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-12-13': FSE_Date(open=41.016, high=41.702, low=41.016, close=41.702, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-12-14': FSE_Date(open=40.204, high=40.204, low=40.204, close=40.204, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-12-15': FSE_Date(open=40.225, high=41.288, low=40.225, close=41.288, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-12-18': FSE_Date(open=40.902, high=40.902, low=40.902, close=40.902, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-12-19': FSE_Date(open=40.582, high=41.622, low=40.582, close=41.582, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-12-20': FSE_Date(open=40.361, high=41.465, low=40.361, close=41.465, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-12-21': FSE_Date(open=39.861, high=39.861, low=39.861, close=39.861, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-12-22': FSE_Date(open=39.932, high=40.999, low=39.932, close=40.997, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-12-25': FSE_Date(open=40.997, high=40.997, low=40.997, close=40.997, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-12-26': FSE_Date(open=40.997, high=40.997, low=40.997, close=40.997, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-12-27': FSE_Date(open=40.266, high=41.263, low=40.266, close=41.263, volume=0.0, adjustment_factor=None, adjustment_type=None),
#  '2017-12-28': FSE_Date(open=40.038, high=40.038, low=40.038, close=40.038, volume=0.0, adjustment_factor=0.992087, adjustment_type=17.0),
#  '2017-12-29': FSE_Date(open=40.143, high=40.143, low=40.026, close=40.026, volume=0.0, adjustment_factor=None, adjustment_type=None)}

# %%
close_deltas = [(tuple(dd.values())[i].close, tuple(dd.values())[i+1].close) for i in range(len(dd)-1)]
# print([i for i in range(5)])
print(f"The largest change between close dates is {round(max([d[1] - d[0] for d in close_deltas]),2)}")
# Out:
# The largest change between close dates is 6.48

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure
for k in json_data.keys():
    print(k + ': ', json_data[k])

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %%
median_list = []

for list in json_list:
    median_list.append(list[5])
    
median_list.sort()
print(median_list)
print(statistics.mean(median_list))

print("Median volume according to file was: " + str(median_list[int((len(median_list))/2)]))
